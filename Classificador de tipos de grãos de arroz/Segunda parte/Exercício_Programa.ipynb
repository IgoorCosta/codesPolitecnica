# %% [markdown]
# # EP - Classificador de Grão de Arroz

# %% [markdown]
# ##Parte 1 (4 pontos): Alinhar os grãos horizontalmente - “alinha.py”

# %%
# Bibliotecas utilizadas na parte 1
import cv2
import numpy as np
import os
from time import time

# %%
# Retorna o centro de massa do grão e sua orientação em rad
def encontrarCentroOrientacao(bin):
  contornos, _ = cv2.findContours(bin, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
  contorno_maior = max(contornos, key=cv2.contourArea)
  M = cv2.moments(contorno_maior)
  cen_x = int(M["m10"] / M["m00"])
  cen_y = int(M["m01"] / M["m00"])
  theta = 0.5*np.arctan2(2*M["mu11"], M["mu20"]-M["mu02"])
  return [cen_x, cen_y, theta]

# %%
# Salva a imagem intermediária figurab para teste
def figura_2b(data, original, name):
  a = original.copy()
  inicial = [int(data[0]-70*np.cos(data[2])), int(data[1]-70*np.sin(data[2]))]
  final = [int(data[0]+70*np.cos(data[2])), int(data[1]+70*np.sin(data[2]))]
  cv2.line(a, inicial, final, [0, 0, 255], 1) # Desenha uma linha indicando a orientação
  for i in range(-2,2,1):
    for j in range(-2,2,1):
      a[data[1]+i,data[0]+j] = [255,0,0]      # Faz um quadrado no centro de massa
  cv2.imwrite(name[:-4]+"-figurab.jpg", a)    # Salva com o nome da figura + (figurab.jpg)

# %%
# Retorna uma lista com todos os arquivos presentes no diretório com a extensão fornecida
def listar_Extensao(diretorio_Base, extensao):
    if (not os.path.exists(diretorio_Base)):                  # Caso não exista o diretório
        print("\nDiretório inexistente\n")
        return []

    os.chdir(diretorio_Base)
    file_path = []
    for file in os.listdir():                                 # Lista todos os arquivos do diretório
        if file.endswith("." + extensao):
            file_path.append(f"{diretorio_Base}/{file}")

    if len(file_path) == 0:                                   # Caso não exista arquivos
        return []

    return file_path

# %%
def alinha(diretorio):
  t0=time()
  arquivos = listar_Extensao(diretorio, 'jpg') # Recebe o nome de todas as imagens

  for name in arquivos:
    original = cv2.imread(name, 1)
    img = cv2.imread(name, 0)
    rows, cols = original.shape[:2]

    # Binarizar a imagem
    lim, bin = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

    #Encontrar o centro e a orientação
    data = encontrarCentroOrientacao(bin)
    #Salvar figuras para teste
    #figura_2b(data, original, name)

    #Rotacionar e centralizar
    rotacao = cv2.getRotationMatrix2D([data[0],data[1]], np.degrees(data[2]), 1.0) # Rotacionar
    rotacao[0][2] = rotacao[0][2]-(data[0]-rows/2)
    rotacao[1][2] = rotacao[1][2]-(data[1]-cols/2)
    img_alinhada = cv2.warpAffine(original, rotacao, (cols,rows)) # Centralizar

    cv2.imwrite(name[:-3]+"png", img_alinhada)

  print('Alinha.py:', len(arquivos), 'arquivos processados. Tempo de processamento:', round(time()-t0, 3), 's.')

# %%
alinha('/content/drive/MyDrive/rice_1to50/orientacao/')
# Out:
# Alinha.py: 6 arquivos processados. Tempo de processamento: 0.059 s.

# %%
alinha('/content/drive/MyDrive/rice_1to50/Arborio/')
alinha('/content/drive/MyDrive/rice_1to50/Basmati/')
alinha('/content/drive/MyDrive/rice_1to50/Ipsala/')
alinha('/content/drive/MyDrive/rice_1to50/Jasmine/')
alinha('/content/drive/MyDrive/rice_1to50/Karacadag/')
# Out:
# Alinha.py: 50 arquivos processados. Tempo de processamento: 0.504 s.
# Alinha.py: 50 arquivos processados. Tempo de processamento: 0.516 s.
# Alinha.py: 50 arquivos processados. Tempo de processamento: 0.547 s.
# Alinha.py: 50 arquivos processados. Tempo de processamento: 0.55 s.
# Alinha.py: 50 arquivos processados. Tempo de processamento: 0.534 s.

# %% [markdown]
# ##Parte 2 (6 pontos): Classificar as imagens não-alinhadas e alinhadas - “class_orig.py e class_alin.py”

# %% [markdown]
# ### Classificar as imagens não-alinhadas

# %%
#Bibliotecas utilizadas
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='3'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
import tensorflow.keras as keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras import optimizers
import numpy as np; import sys; import os; from time import time
from tensorflow.keras.utils import plot_model

# %%
# Criar valores AX AY e QX QY
def fiveFoldCrossValidation(inicio, fim, diretorio, extensao):
  #Gera a lista com todas as imagens para treinamento e teste
  arquivos = listar_Extensao(diretorio+'Arborio/', extensao)         # indice 0
  arquivos.extend(listar_Extensao(diretorio+'Basmati/', extensao))   # indice 1
  arquivos.extend(listar_Extensao(diretorio+'Ipsala/', extensao))    # indice 2
  arquivos.extend(listar_Extensao(diretorio+'Jasmine/', extensao))   # indice 3
  arquivos.extend(listar_Extensao(diretorio+'Karacadag/', extensao)) # indice 4

  first_train = 1
  first_test = 1
  for i in range(0, len(arquivos)):
    if i%50 >= inicio and i%50 <= fim:  #Valores entre inicio e fim - TESTE
      if first_test == 1:
        QX = np.array(cv2.imread(arquivos[i], 0))
        QX = QX.reshape(1, QX.shape[0], QX.shape[1])
        QY = np.array(int(i/50)) # Pega indice da imagem (0 a 4)
        first_test = 0
      else:
        QX2 = np.array(cv2.imread(arquivos[i], 0))
        QX2 = QX2.reshape(1, QX2.shape[0], QX2.shape[1])
        QX = np.concatenate([QX, QX2], 0)
        QY = np.append(QY, int(i/50))

    else: #Valores fora do inicio e fim - TREINAMENTO
      if first_train == 1:
        AX = np.array(cv2.imread(arquivos[i], 0))
        AX = AX.reshape(1, AX.shape[0], AX.shape[1])
        AY = np.array(int(i/50))
        first_train = 0
      else:
        AX2 = np.array(cv2.imread(arquivos[i], 0))
        AX2 = AX2.reshape(1, AX2.shape[0], AX2.shape[1])
        AX = np.concatenate([AX, AX2], 0)
        AY = np.append(AY, int(i/50))

  print("Tamanho das matrizes: AX =", AX.shape, "AY =", AY.shape, "QX =", QX.shape, "QY =", QY.shape)
  return AX, AY, QX, QY

# %%
def modeloConvolucional(AX, AY, QX, QY):
  AX = 255 - AX
  QX = 255 - QX
  nclasses = 10
  nl, nc = AX.shape[1], AX.shape[2]

  AX = (AX.astype('float32')/255.0)-0.5
  QX = (QX.astype('float32')/255.0)-0.5
  AX = np.expand_dims(AX,axis=3)
  QX = np.expand_dims(QX,axis=3)

  # Criando modelo, nomeando todos os parâmetros da rede
  model = Sequential()
  model.add(Conv2D(20, kernel_size=(5,5), activation='relu', input_shape=(nl, nc, 1)))
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Conv2D(40, kernel_size=(5,5), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Flatten())
  model.add(Dense(200, activation='relu'))
  model.add(Dense(nclasses, activation='softmax'))
  model.compile(optimizer=optimizers.Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  #plot_model(model, to_file='cnn1.png', show_shapes=True);
  #model.summary()

  t0 = time()
  model.fit(AX, AY, batch_size=100, epochs=30, verbose=2)
  print("Tempo de treino: %.2f s"%(time()-t0))

  score = model.evaluate(QX, QY, verbose=False)
  print('Test loss: %.4f'%(score[0]))
  print('Test accuracy: %.2f %%'%(100*score[1]))
  print('Test error: %.2f %%'%(100*(1-score[1])))

  t2 = time()
  QP = np.argmax(model.predict(QX), 1)
  #print("Tempo de predicao: %.2f s"%(time()-t2))
  #nerro = np.count_nonzero(QP-QY)
  #print("nerro=%d"%(nerro))
  #model.save('cnn1.h5')

  return round(score[0],4), round(score[1],4)

# %%
def class_orig(diretorio):
  AX, AY, QX, QY = fiveFoldCrossValidation(0, 9, diretorio, 'jpg')    #S1
  pS1, aS1 = modeloConvolucional(AX, AY, QX, QY)
  AX, AY, QX, QY = fiveFoldCrossValidation(10, 19, diretorio, 'jpg')  #S2
  pS2, aS2 = modeloConvolucional(AX, AY, QX, QY)
  AX, AY, QX, QY = fiveFoldCrossValidation(20, 29, diretorio, 'jpg')  #S3
  pS3, aS3 = modeloConvolucional(AX, AY, QX, QY)
  AX, AY, QX, QY = fiveFoldCrossValidation(30, 39, diretorio, 'jpg')  #S4
  pS4, aS4 = modeloConvolucional(AX, AY, QX, QY)
  AX, AY, QX, QY = fiveFoldCrossValidation(40, 49, diretorio, 'jpg')  #S5
  pS5, aS5 = modeloConvolucional(AX, AY, QX, QY)

  print('\n\nResultados class_orig: 5-fold cross validation:\n')
  print('Perda do Teste: ',pS1, pS2, pS3, pS4, pS5, 'Média:', round(np.mean([pS1, pS2, pS3, pS4, pS5]),4))
  print('Acurácia do Teste: ',aS1, aS2, aS3, aS4, aS5, 'Média:', round(np.mean([aS1, aS2, aS3, aS4, aS5]),4))
  print('Erro do Teste: ',round(1-aS1,4), round(1-aS2,4), round(1-aS3,4), round(1-aS4,4), round(1-aS5,4), 'Média:', round(np.mean([1-aS1, 1-aS2, 1-aS3, 1-aS4, 1-aS5]),4))

class_orig('/content/drive/MyDrive/rice_1to50/')
# Out:
# Tamanho das matrizes: AX = (200, 250, 250) AY = (200,) QX = (50, 250, 250) QY = (50,)
# Epoch 1/30
# 2/2 - 2s - loss: 3.2982 - accuracy: 0.2900 - 2s/epoch - 1s/step
# Epoch 2/30
# 2/2 - 0s - loss: 4.8271 - accuracy: 0.1650 - 229ms/epoch - 115ms/step
# Epoch 3/30
# 2/2 - 0s - loss: 2.0030 - accuracy: 0.4000 - 212ms/epoch - 106ms/step
# Epoch 4/30
# 2/2 - 0s - loss: 1.5263 - accuracy: 0.5350 - 214ms/epoch - 107ms/step
# Epoch 5/30
# 2/2 - 0s - loss: 1.0838 - accuracy: 0.6700 - 211ms/epoch - 106ms/step
# Epoch 6/30
# 2/2 - 0s - loss: 0.6528 - accuracy: 0.8650 - 208ms/epoch - 104ms/step
# Epoch 7/30
# 2/2 - 0s - loss: 0.3682 - accuracy: 0.9600 - 214ms/epoch - 107ms/step
# Epoch 8/30
# 2/2 - 0s - loss: 0.2743 - accuracy: 0.9450 - 214ms/epoch - 107ms/step
# Epoch 9/30
# 2/2 - 0s - loss: 0.1937 - accuracy: 0.9450 - 210ms/epoch - 105ms/step
# Epoch 10/30
# 2/2 - 0s - loss: 0.1361 - accuracy: 0.9600 - 210ms/epoch - 105ms/step
# Epoch 11/30
# 2/2 - 0s - loss: 0.1077 - accuracy: 0.9700 - 212ms/epoch - 106ms/step
# Epoch 12/30
# 2/2 - 0s - loss: 0.1053 - accuracy: 0.9600 - 209ms/epoch - 104ms/step
# Epoch 13/30
# 2/2 - 0s - loss: 0.0535 - accuracy: 0.9800 - 212ms/epoch - 106ms/step
# Epoch 14/30
# 2/2 - 0s - loss: 0.0434 - accuracy: 0.9900 - 211ms/epoch - 106ms/step
# Epoch 15/30
# 2/2 - 0s - loss: 0.0325 - accuracy: 0.9900 - 210ms/epoch - 105ms/step
# Epoch 16/30
# 2/2 - 0s - loss: 0.0239 - accuracy: 0.9950 - 210ms/epoch - 105ms/step
# Epoch 17/30
# 2/2 - 0s - loss: 0.0186 - accuracy: 1.0000 - 213ms/epoch - 106ms/step
# Epoch 18/30
# 2/2 - 0s - loss: 0.0084 - accuracy: 1.0000 - 209ms/epoch - 104ms/step
# Epoch 19/30
# 2/2 - 0s - loss: 0.0106 - accuracy: 1.0000 - 216ms/epoch - 108ms/step
# Epoch 20/30
# 2/2 - 0s - loss: 0.0041 - accuracy: 1.0000 - 214ms/epoch - 107ms/step
# Epoch 21/30
# 2/2 - 0s - loss: 0.0107 - accuracy: 1.0000 - 213ms/epoch - 106ms/step
# Epoch 22/30
# 2/2 - 0s - loss: 0.0039 - accuracy: 1.0000 - 210ms/epoch - 105ms/step
# Epoch 23/30
# 2/2 - 0s - loss: 0.0038 - accuracy: 1.0000 - 216ms/epoch - 108ms/step
# Epoch 24/30
# 2/2 - 0s - loss: 0.0039 - accuracy: 1.0000 - 213ms/epoch - 106ms/step
# Epoch 25/30
# 2/2 - 0s - loss: 0.0018 - accuracy: 1.0000 - 205ms/epoch - 103ms/step
# Epoch 26/30
# 2/2 - 0s - loss: 0.0014 - accuracy: 1.0000 - 209ms/epoch - 104ms/step
# Epoch 27/30
# 2/2 - 0s - loss: 0.0018 - accuracy: 1.0000 - 208ms/epoch - 104ms/step
# Epoch 28/30
# 2/2 - 0s - loss: 0.0022 - accuracy: 1.0000 - 216ms/epoch - 108ms/step
# Epoch 29/30
# 2/2 - 0s - loss: 0.0016 - accuracy: 1.0000 - 216ms/epoch - 108ms/step
# Epoch 30/30
# 2/2 - 0s - loss: 0.0010 - accuracy: 1.0000 - 203ms/epoch - 101ms/step
# Tempo de treino: 8.63 s
# Test loss: 0.4690
# Test accuracy: 86.00 %
# Test error: 14.00 %
# 2/2 [==============================] - 0s 9ms/step
# Tamanho das matrizes: AX = (200, 250, 250) AY = (200,) QX = (50, 250, 250) QY = (50,)
# Epoch 1/30
# 2/2 - 2s - loss: 3.7195 - accuracy: 0.1200 - 2s/epoch - 789ms/step
# Epoch 2/30
# 2/2 - 0s - loss: 6.1652 - accuracy: 0.2550 - 239ms/epoch - 120ms/step
# Epoch 3/30
# 2/2 - 0s - loss: 4.6284 - accuracy: 0.2900 - 213ms/epoch - 106ms/step
# Epoch 4/30
# 2/2 - 0s - loss: 2.0683 - accuracy: 0.3000 - 217ms/epoch - 109ms/step
# Epoch 5/30
# 2/2 - 0s - loss: 1.1149 - accuracy: 0.7000 - 222ms/epoch - 111ms/step
# Epoch 6/30
# 2/2 - 0s - loss: 0.7770 - accuracy: 0.7750 - 222ms/epoch - 111ms/step
# Epoch 7/30
# 2/2 - 0s - loss: 0.5948 - accuracy: 0.8400 - 217ms/epoch - 108ms/step
# Epoch 8/30
# 2/2 - 0s - loss: 0.4849 - accuracy: 0.7550 - 218ms/epoch - 109ms/step
# Epoch 9/30
# 2/2 - 0s - loss: 0.2791 - accuracy: 0.9300 - 223ms/epoch - 112ms/step
# Epoch 10/30
# 2/2 - 0s - loss: 0.2414 - accuracy: 0.9150 - 231ms/epoch - 116ms/step
# Epoch 11/30
# 2/2 - 0s - loss: 0.1689 - accuracy: 0.9550 - 217ms/epoch - 109ms/step
# Epoch 12/30
# 2/2 - 0s - loss: 0.0925 - accuracy: 0.9900 - 217ms/epoch - 109ms/step
# Epoch 13/30
# 2/2 - 0s - loss: 0.0659 - accuracy: 1.0000 - 217ms/epoch - 108ms/step
# Epoch 14/30
# 2/2 - 0s - loss: 0.0529 - accuracy: 1.0000 - 217ms/epoch - 108ms/step
# Epoch 15/30
# 2/2 - 0s - loss: 0.0367 - accuracy: 1.0000 - 218ms/epoch - 109ms/step
# Epoch 16/30
# 2/2 - 0s - loss: 0.0292 - accuracy: 1.0000 - 219ms/epoch - 109ms/step
# Epoch 17/30
# 2/2 - 0s - loss: 0.0204 - accuracy: 1.0000 - 219ms/epoch - 110ms/step
# Epoch 18/30
# 2/2 - 0s - loss: 0.0181 - accuracy: 1.0000 - 219ms/epoch - 110ms/step
# Epoch 19/30
# 2/2 - 0s - loss: 0.0122 - accuracy: 1.0000 - 218ms/epoch - 109ms/step
# Epoch 20/30
# 2/2 - 0s - loss: 0.0087 - accuracy: 1.0000 - 218ms/epoch - 109ms/step
# Epoch 21/30
# 2/2 - 0s - loss: 0.0085 - accuracy: 1.0000 - 211ms/epoch - 106ms/step
# Epoch 22/30
# 2/2 - 0s - loss: 0.0057 - accuracy: 1.0000 - 223ms/epoch - 111ms/step
# Epoch 23/30
# 2/2 - 0s - loss: 0.0056 - accuracy: 1.0000 - 215ms/epoch - 107ms/step
# Epoch 24/30
# 2/2 - 0s - loss: 0.0049 - accuracy: 1.0000 - 215ms/epoch - 107ms/step
# Epoch 25/30
# 2/2 - 0s - loss: 0.0033 - accuracy: 1.0000 - 211ms/epoch - 105ms/step
# Epoch 26/30
# 2/2 - 0s - loss: 0.0033 - accuracy: 1.0000 - 211ms/epoch - 105ms/step
# Epoch 27/30
# 2/2 - 0s - loss: 0.0032 - accuracy: 1.0000 - 214ms/epoch - 107ms/step
# Epoch 28/30
# 2/2 - 0s - loss: 0.0022 - accuracy: 1.0000 - 215ms/epoch - 108ms/step
# Epoch 29/30
# 2/2 - 0s - loss: 0.0022 - accuracy: 1.0000 - 215ms/epoch - 107ms/step
# Epoch 30/30
# 2/2 - 0s - loss: 0.0021 - accuracy: 1.0000 - 203ms/epoch - 101ms/step
# Tempo de treino: 10.93 s
# Test loss: 0.1057
# Test accuracy: 96.00 %
# Test error: 4.00 %
# 2/2 [==============================] - 0s 13ms/step
# Tamanho das matrizes: AX = (200, 250, 250) AY = (200,) QX = (50, 250, 250) QY = (50,)
# Epoch 1/30
# 2/2 - 2s - loss: 2.1230 - accuracy: 0.1950 - 2s/epoch - 789ms/step
# Epoch 2/30
# 2/2 - 0s - loss: 2.5087 - accuracy: 0.3000 - 224ms/epoch - 112ms/step
# Epoch 3/30
# 2/2 - 0s - loss: 1.2171 - accuracy: 0.4650 - 209ms/epoch - 104ms/step
# Epoch 4/30
# 2/2 - 0s - loss: 0.6604 - accuracy: 0.8050 - 212ms/epoch - 106ms/step
# Epoch 5/30
# 2/2 - 0s - loss: 0.4732 - accuracy: 0.9050 - 212ms/epoch - 106ms/step
# Epoch 6/30
# 2/2 - 0s - loss: 0.3169 - accuracy: 0.9450 - 211ms/epoch - 106ms/step
# Epoch 7/30
# 2/2 - 0s - loss: 0.2098 - accuracy: 0.9700 - 216ms/epoch - 108ms/step
# Epoch 8/30
# 2/2 - 0s - loss: 0.1187 - accuracy: 0.9900 - 213ms/epoch - 107ms/step
# Epoch 9/30
# 2/2 - 0s - loss: 0.0965 - accuracy: 0.9850 - 211ms/epoch - 106ms/step
# Epoch 10/30
# 2/2 - 0s - loss: 0.0562 - accuracy: 0.9850 - 227ms/epoch - 113ms/step
# Epoch 11/30
# 2/2 - 0s - loss: 0.0575 - accuracy: 0.9900 - 215ms/epoch - 108ms/step
# Epoch 12/30
# 2/2 - 0s - loss: 0.0287 - accuracy: 1.0000 - 214ms/epoch - 107ms/step
# Epoch 13/30
# 2/2 - 0s - loss: 0.0223 - accuracy: 1.0000 - 212ms/epoch - 106ms/step
# Epoch 14/30
# 2/2 - 0s - loss: 0.0185 - accuracy: 1.0000 - 216ms/epoch - 108ms/step
# Epoch 15/30
# 2/2 - 0s - loss: 0.0113 - accuracy: 1.0000 - 211ms/epoch - 106ms/step
# Epoch 16/30
# 2/2 - 0s - loss: 0.0087 - accuracy: 1.0000 - 216ms/epoch - 108ms/step
# Epoch 17/30
# 2/2 - 0s - loss: 0.0067 - accuracy: 1.0000 - 216ms/epoch - 108ms/step
# Epoch 18/30
# 2/2 - 0s - loss: 0.0058 - accuracy: 1.0000 - 217ms/epoch - 108ms/step
# Epoch 19/30
# 2/2 - 0s - loss: 0.0046 - accuracy: 1.0000 - 235ms/epoch - 118ms/step
# Epoch 20/30
# 2/2 - 0s - loss: 0.0034 - accuracy: 1.0000 - 223ms/epoch - 112ms/step
# Epoch 21/30
# 2/2 - 0s - loss: 0.0027 - accuracy: 1.0000 - 218ms/epoch - 109ms/step
# Epoch 22/30
# 2/2 - 0s - loss: 0.0022 - accuracy: 1.0000 - 206ms/epoch - 103ms/step
# Epoch 23/30
# 2/2 - 0s - loss: 0.0019 - accuracy: 1.0000 - 219ms/epoch - 110ms/step
# Epoch 24/30
# 2/2 - 0s - loss: 0.0017 - accuracy: 1.0000 - 211ms/epoch - 106ms/step
# Epoch 25/30
# 2/2 - 0s - loss: 0.0015 - accuracy: 1.0000 - 217ms/epoch - 109ms/step
# Epoch 26/30
# 2/2 - 0s - loss: 0.0014 - accuracy: 1.0000 - 221ms/epoch - 111ms/step
# Epoch 27/30
# 2/2 - 0s - loss: 0.0012 - accuracy: 1.0000 - 218ms/epoch - 109ms/step
# Epoch 28/30
# 2/2 - 0s - loss: 0.0011 - accuracy: 1.0000 - 216ms/epoch - 108ms/step
# Epoch 29/30
# 2/2 - 0s - loss: 9.7069e-04 - accuracy: 1.0000 - 213ms/epoch - 107ms/step
# Epoch 30/30
# 2/2 - 0s - loss: 9.0264e-04 - accuracy: 1.0000 - 205ms/epoch - 102ms/step
# Tempo de treino: 8.11 s
# Test loss: 0.3524
# Test accuracy: 88.00 %
# Test error: 12.00 %
# 2/2 [==============================] - 0s 8ms/step
# Tamanho das matrizes: AX = (200, 250, 250) AY = (200,) QX = (50, 250, 250) QY = (50,)
# Epoch 1/30
# 2/2 - 2s - loss: 7.9786 - accuracy: 0.2050 - 2s/epoch - 785ms/step
# Epoch 2/30
# 2/2 - 0s - loss: 2.8370 - accuracy: 0.4000 - 217ms/epoch - 109ms/step
# Epoch 3/30
# 2/2 - 0s - loss: 1.9540 - accuracy: 0.3900 - 212ms/epoch - 106ms/step
# Epoch 4/30
# 2/2 - 0s - loss: 1.3668 - accuracy: 0.6050 - 216ms/epoch - 108ms/step
# Epoch 5/30
# 2/2 - 0s - loss: 0.9389 - accuracy: 0.7350 - 207ms/epoch - 103ms/step
# Epoch 6/30
# 2/2 - 0s - loss: 0.5772 - accuracy: 0.8650 - 212ms/epoch - 106ms/step
# Epoch 7/30
# 2/2 - 0s - loss: 0.4366 - accuracy: 0.8500 - 209ms/epoch - 105ms/step
# Epoch 8/30
# 2/2 - 0s - loss: 0.3189 - accuracy: 0.8900 - 207ms/epoch - 103ms/step
# Epoch 9/30
# 2/2 - 0s - loss: 0.2418 - accuracy: 0.9150 - 209ms/epoch - 105ms/step
# Epoch 10/30
# 2/2 - 0s - loss: 0.1332 - accuracy: 0.9650 - 209ms/epoch - 104ms/step
# Epoch 11/30
# 2/2 - 0s - loss: 0.1043 - accuracy: 0.9850 - 210ms/epoch - 105ms/step
# Epoch 12/30
# 2/2 - 0s - loss: 0.0756 - accuracy: 0.9700 - 212ms/epoch - 106ms/step
# Epoch 13/30
# 2/2 - 0s - loss: 0.0713 - accuracy: 0.9750 - 210ms/epoch - 105ms/step
# Epoch 14/30
# 2/2 - 0s - loss: 0.0407 - accuracy: 1.0000 - 207ms/epoch - 103ms/step
# Epoch 15/30
# 2/2 - 0s - loss: 0.0369 - accuracy: 0.9900 - 216ms/epoch - 108ms/step
# Epoch 16/30
# 2/2 - 0s - loss: 0.0233 - accuracy: 1.0000 - 210ms/epoch - 105ms/step
# Epoch 17/30
# 2/2 - 0s - loss: 0.0245 - accuracy: 1.0000 - 211ms/epoch - 106ms/step
# Epoch 18/30
# 2/2 - 0s - loss: 0.0205 - accuracy: 0.9900 - 210ms/epoch - 105ms/step
# Epoch 19/30
# 2/2 - 0s - loss: 0.0145 - accuracy: 0.9950 - 213ms/epoch - 107ms/step
# Epoch 20/30
# 2/2 - 0s - loss: 0.0094 - accuracy: 1.0000 - 208ms/epoch - 104ms/step
# Epoch 21/30
# 2/2 - 0s - loss: 0.0096 - accuracy: 1.0000 - 212ms/epoch - 106ms/step
# Epoch 22/30
# 2/2 - 0s - loss: 0.0058 - accuracy: 1.0000 - 216ms/epoch - 108ms/step
# Epoch 23/30
# 2/2 - 0s - loss: 0.0060 - accuracy: 1.0000 - 207ms/epoch - 104ms/step
# Epoch 24/30
# 2/2 - 0s - loss: 0.0053 - accuracy: 1.0000 - 210ms/epoch - 105ms/step
# Epoch 25/30
# 2/2 - 0s - loss: 0.0038 - accuracy: 1.0000 - 212ms/epoch - 106ms/step
# Epoch 26/30
# 2/2 - 0s - loss: 0.0036 - accuracy: 1.0000 - 213ms/epoch - 107ms/step
# Epoch 27/30
# 2/2 - 0s - loss: 0.0034 - accuracy: 1.0000 - 211ms/epoch - 105ms/step
# Epoch 28/30
# 2/2 - 0s - loss: 0.0027 - accuracy: 1.0000 - 211ms/epoch - 106ms/step
# Epoch 29/30
# 2/2 - 0s - loss: 0.0024 - accuracy: 1.0000 - 211ms/epoch - 106ms/step
# Epoch 30/30
# 2/2 - 0s - loss: 0.0023 - accuracy: 1.0000 - 203ms/epoch - 101ms/step
# Tempo de treino: 10.90 s
# Test loss: 0.6010
# Test accuracy: 86.00 %
# Test error: 14.00 %
# 2/2 [==============================] - 0s 13ms/step
# Tamanho das matrizes: AX = (200, 250, 250) AY = (200,) QX = (50, 250, 250) QY = (50,)
# Epoch 1/30
# 2/2 - 2s - loss: 3.6821 - accuracy: 0.2050 - 2s/epoch - 788ms/step
# Epoch 2/30
# 2/2 - 0s - loss: 3.3240 - accuracy: 0.2850 - 224ms/epoch - 112ms/step
# Epoch 3/30
# 2/2 - 0s - loss: 2.1235 - accuracy: 0.3500 - 209ms/epoch - 105ms/step
# Epoch 4/30
# 2/2 - 0s - loss: 1.3304 - accuracy: 0.6750 - 200ms/epoch - 100ms/step
# Epoch 5/30
# 2/2 - 0s - loss: 0.9465 - accuracy: 0.7200 - 208ms/epoch - 104ms/step
# Epoch 6/30
# 2/2 - 0s - loss: 0.5817 - accuracy: 0.8600 - 204ms/epoch - 102ms/step
# Epoch 7/30
# 2/2 - 0s - loss: 0.3866 - accuracy: 0.9200 - 205ms/epoch - 102ms/step
# Epoch 8/30
# 2/2 - 0s - loss: 0.2841 - accuracy: 0.8850 - 209ms/epoch - 104ms/step
# Epoch 9/30
# 2/2 - 0s - loss: 0.2047 - accuracy: 0.9250 - 216ms/epoch - 108ms/step
# Epoch 10/30
# 2/2 - 0s - loss: 0.1230 - accuracy: 0.9500 - 208ms/epoch - 104ms/step
# Epoch 11/30
# 2/2 - 0s - loss: 0.1263 - accuracy: 0.9500 - 209ms/epoch - 104ms/step
# Epoch 12/30
# 2/2 - 0s - loss: 0.0948 - accuracy: 0.9600 - 207ms/epoch - 103ms/step
# Epoch 13/30
# 2/2 - 0s - loss: 0.0561 - accuracy: 0.9850 - 209ms/epoch - 104ms/step
# Epoch 14/30
# 2/2 - 0s - loss: 0.0634 - accuracy: 0.9750 - 211ms/epoch - 106ms/step
# Epoch 15/30
# 2/2 - 0s - loss: 0.0460 - accuracy: 0.9900 - 211ms/epoch - 106ms/step
# Epoch 16/30
# 2/2 - 0s - loss: 0.0390 - accuracy: 0.9900 - 208ms/epoch - 104ms/step
# Epoch 17/30
# 2/2 - 0s - loss: 0.0296 - accuracy: 0.9850 - 208ms/epoch - 104ms/step
# Epoch 18/30
# 2/2 - 0s - loss: 0.0244 - accuracy: 0.9850 - 205ms/epoch - 102ms/step
# Epoch 19/30
# 2/2 - 0s - loss: 0.0182 - accuracy: 1.0000 - 209ms/epoch - 104ms/step
# Epoch 20/30
# 2/2 - 0s - loss: 0.0182 - accuracy: 1.0000 - 208ms/epoch - 104ms/step
# Epoch 21/30
# 2/2 - 0s - loss: 0.0083 - accuracy: 1.0000 - 209ms/epoch - 105ms/step
# Epoch 22/30
# 2/2 - 0s - loss: 0.0108 - accuracy: 0.9950 - 210ms/epoch - 105ms/step
# Epoch 23/30
# 2/2 - 0s - loss: 0.0099 - accuracy: 1.0000 - 212ms/epoch - 106ms/step
# Epoch 24/30
# 2/2 - 0s - loss: 0.0047 - accuracy: 1.0000 - 215ms/epoch - 107ms/step
# Epoch 25/30
# 2/2 - 0s - loss: 0.0055 - accuracy: 1.0000 - 214ms/epoch - 107ms/step
# Epoch 26/30
# 2/2 - 0s - loss: 0.0058 - accuracy: 1.0000 - 206ms/epoch - 103ms/step
# Epoch 27/30
# 2/2 - 0s - loss: 0.0034 - accuracy: 1.0000 - 211ms/epoch - 105ms/step
# Epoch 28/30
# 2/2 - 0s - loss: 0.0025 - accuracy: 1.0000 - 212ms/epoch - 106ms/step
# Epoch 29/30
# 2/2 - 0s - loss: 0.0027 - accuracy: 1.0000 - 208ms/epoch - 104ms/step
# Epoch 30/30
# 2/2 - 0s - loss: 0.0029 - accuracy: 1.0000 - 205ms/epoch - 102ms/step
# Tempo de treino: 10.91 s
# Test loss: 0.0968
# Test accuracy: 98.00 %
# Test error: 2.00 %
# 2/2 [==============================] - 0s 13ms/step
#
#
# Resultados class_orig: 5-fold cross validation:
#
# Perda do Teste:  0.469 0.1057 0.3524 0.601 0.0968 Média: 0.325
# Acurácia do Teste:  0.86 0.96 0.88 0.86 0.98 Média: 0.908
# Erro do Teste:  0.14 0.04 0.12 0.14 0.02 Média: 0.092

# %%
def class_alin(diretorio):
  AX, AY, QX, QY = fiveFoldCrossValidation(0, 9, diretorio, 'png')    #S1
  pS1, aS1 = modeloConvolucional(AX, AY, QX, QY)
  AX, AY, QX, QY = fiveFoldCrossValidation(10, 19, diretorio, 'png')  #S2
  pS2, aS2 = modeloConvolucional(AX, AY, QX, QY)
  AX, AY, QX, QY = fiveFoldCrossValidation(20, 29, diretorio, 'png')  #S3
  pS3, aS3 = modeloConvolucional(AX, AY, QX, QY)
  AX, AY, QX, QY = fiveFoldCrossValidation(30, 39, diretorio, 'png')  #S4
  pS4, aS4 = modeloConvolucional(AX, AY, QX, QY)
  AX, AY, QX, QY = fiveFoldCrossValidation(40, 49, diretorio, 'png')  #S5
  pS5, aS5 = modeloConvolucional(AX, AY, QX, QY)

  print('\n\nResultados class_alin:  5-fold cross validation:\n')
  print('Perda do Teste: ',pS1, pS2, pS3, pS4, pS5, 'Média:', round(np.mean([pS1, pS2, pS3, pS4, pS5]),4))
  print('Acurácia do Teste: ',aS1, aS2, aS3, aS4, aS5, 'Média:', round(np.mean([aS1, aS2, aS3, aS4, aS5]),4))
  print('Erro do Teste: ',round(1-aS1,4), round(1-aS2,4), round(1-aS3,4), round(1-aS4,4), round(1-aS5,4), 'Média:', round(np.mean([1-aS1, 1-aS2, 1-aS3, 1-aS4, 1-aS5]),4))

class_alin('/content/drive/MyDrive/rice_1to50/')
# Out:
# Tamanho das matrizes: AX = (200, 250, 250) AY = (200,) QX = (50, 250, 250) QY = (50,)
# Epoch 1/30
# 2/2 - 2s - loss: 2.5446 - accuracy: 0.1950 - 2s/epoch - 814ms/step
# Epoch 2/30
# 2/2 - 0s - loss: 4.3688 - accuracy: 0.4200 - 220ms/epoch - 110ms/step
# Epoch 3/30
# 2/2 - 0s - loss: 1.6213 - accuracy: 0.6000 - 210ms/epoch - 105ms/step
# Epoch 4/30
# 2/2 - 0s - loss: 0.7001 - accuracy: 0.8300 - 206ms/epoch - 103ms/step
# Epoch 5/30
# 2/2 - 0s - loss: 0.3721 - accuracy: 0.8950 - 208ms/epoch - 104ms/step
# Epoch 6/30
# 2/2 - 0s - loss: 0.2318 - accuracy: 0.9500 - 207ms/epoch - 103ms/step
# Epoch 7/30
# 2/2 - 0s - loss: 0.1367 - accuracy: 0.9800 - 210ms/epoch - 105ms/step
# Epoch 8/30
# 2/2 - 0s - loss: 0.3053 - accuracy: 0.8250 - 206ms/epoch - 103ms/step
# Epoch 9/30
# 2/2 - 0s - loss: 0.1164 - accuracy: 0.9400 - 210ms/epoch - 105ms/step
# Epoch 10/30
# 2/2 - 0s - loss: 0.1228 - accuracy: 0.9450 - 216ms/epoch - 108ms/step
# Epoch 11/30
# 2/2 - 0s - loss: 0.0529 - accuracy: 0.9850 - 208ms/epoch - 104ms/step
# Epoch 12/30
# 2/2 - 0s - loss: 0.0614 - accuracy: 0.9850 - 217ms/epoch - 108ms/step
# Epoch 13/30
# 2/2 - 0s - loss: 0.0362 - accuracy: 0.9900 - 207ms/epoch - 104ms/step
# Epoch 14/30
# 2/2 - 0s - loss: 0.0553 - accuracy: 0.9800 - 212ms/epoch - 106ms/step
# Epoch 15/30
# 2/2 - 0s - loss: 0.0543 - accuracy: 0.9800 - 219ms/epoch - 109ms/step
# Epoch 16/30
# 2/2 - 0s - loss: 0.0381 - accuracy: 0.9950 - 219ms/epoch - 109ms/step
# Epoch 17/30
# 2/2 - 0s - loss: 0.0391 - accuracy: 0.9900 - 216ms/epoch - 108ms/step
# Epoch 18/30
# 2/2 - 0s - loss: 0.0302 - accuracy: 0.9950 - 217ms/epoch - 108ms/step
# Epoch 19/30
# 2/2 - 0s - loss: 0.0156 - accuracy: 0.9950 - 222ms/epoch - 111ms/step
# Epoch 20/30
# 2/2 - 0s - loss: 0.0190 - accuracy: 0.9950 - 219ms/epoch - 110ms/step
# Epoch 21/30
# 2/2 - 0s - loss: 0.0189 - accuracy: 0.9950 - 215ms/epoch - 107ms/step
# Epoch 22/30
# 2/2 - 0s - loss: 0.0153 - accuracy: 0.9950 - 220ms/epoch - 110ms/step
# Epoch 23/30
# 2/2 - 0s - loss: 0.0146 - accuracy: 0.9950 - 217ms/epoch - 109ms/step
# Epoch 24/30
# 2/2 - 0s - loss: 0.0127 - accuracy: 0.9950 - 214ms/epoch - 107ms/step
# Epoch 25/30
# 2/2 - 0s - loss: 0.0104 - accuracy: 1.0000 - 217ms/epoch - 108ms/step
# Epoch 26/30
# 2/2 - 0s - loss: 0.0095 - accuracy: 0.9950 - 217ms/epoch - 109ms/step
# Epoch 27/30
# 2/2 - 0s - loss: 0.0092 - accuracy: 0.9950 - 213ms/epoch - 106ms/step
# Epoch 28/30
# 2/2 - 0s - loss: 0.0077 - accuracy: 1.0000 - 213ms/epoch - 107ms/step
# Epoch 29/30
# 2/2 - 0s - loss: 0.0076 - accuracy: 1.0000 - 213ms/epoch - 107ms/step
# Epoch 30/30
# 2/2 - 0s - loss: 0.0069 - accuracy: 1.0000 - 201ms/epoch - 101ms/step
# Tempo de treino: 8.09 s
# Test loss: 0.6183
# Test accuracy: 94.00 %
# Test error: 6.00 %
# 2/2 [==============================] - 0s 10ms/step
# Tamanho das matrizes: AX = (200, 250, 250) AY = (200,) QX = (50, 250, 250) QY = (50,)
# Epoch 1/30
# 2/2 - 2s - loss: 2.0362 - accuracy: 0.1750 - 2s/epoch - 795ms/step
# Epoch 2/30
# 2/2 - 0s - loss: 2.0002 - accuracy: 0.5900 - 231ms/epoch - 115ms/step
# Epoch 3/30
# 2/2 - 0s - loss: 0.8220 - accuracy: 0.8150 - 209ms/epoch - 104ms/step
# Epoch 4/30
# 2/2 - 0s - loss: 0.5694 - accuracy: 0.6950 - 207ms/epoch - 103ms/step
# Epoch 5/30
# 2/2 - 0s - loss: 0.3675 - accuracy: 0.7900 - 208ms/epoch - 104ms/step
# Epoch 6/30
# 2/2 - 0s - loss: 0.2382 - accuracy: 0.8850 - 208ms/epoch - 104ms/step
# Epoch 7/30
# 2/2 - 0s - loss: 0.1616 - accuracy: 0.9600 - 207ms/epoch - 104ms/step
# Epoch 8/30
# 2/2 - 0s - loss: 0.1351 - accuracy: 0.9550 - 217ms/epoch - 109ms/step
# Epoch 9/30
# 2/2 - 0s - loss: 0.0868 - accuracy: 0.9750 - 206ms/epoch - 103ms/step
# Epoch 10/30
# 2/2 - 0s - loss: 0.0753 - accuracy: 0.9700 - 210ms/epoch - 105ms/step
# Epoch 11/30
# 2/2 - 0s - loss: 0.0691 - accuracy: 0.9850 - 206ms/epoch - 103ms/step
# Epoch 12/30
# 2/2 - 0s - loss: 0.0498 - accuracy: 0.9950 - 209ms/epoch - 105ms/step
# Epoch 13/30
# 2/2 - 0s - loss: 0.0422 - accuracy: 0.9900 - 207ms/epoch - 104ms/step
# Epoch 14/30
# 2/2 - 0s - loss: 0.0369 - accuracy: 0.9800 - 206ms/epoch - 103ms/step
# Epoch 15/30
# 2/2 - 0s - loss: 0.0308 - accuracy: 0.9900 - 210ms/epoch - 105ms/step
# Epoch 16/30
# 2/2 - 0s - loss: 0.0240 - accuracy: 0.9950 - 211ms/epoch - 106ms/step
# Epoch 17/30
# 2/2 - 0s - loss: 0.0243 - accuracy: 0.9950 - 210ms/epoch - 105ms/step
# Epoch 18/30
# 2/2 - 0s - loss: 0.0182 - accuracy: 0.9950 - 209ms/epoch - 105ms/step
# Epoch 19/30
# 2/2 - 0s - loss: 0.0150 - accuracy: 0.9950 - 211ms/epoch - 105ms/step
# Epoch 20/30
# 2/2 - 0s - loss: 0.0145 - accuracy: 1.0000 - 208ms/epoch - 104ms/step
# Epoch 21/30
# 2/2 - 0s - loss: 0.0128 - accuracy: 1.0000 - 210ms/epoch - 105ms/step
# Epoch 22/30
# 2/2 - 0s - loss: 0.0101 - accuracy: 1.0000 - 214ms/epoch - 107ms/step
# Epoch 23/30
# 2/2 - 0s - loss: 0.0095 - accuracy: 1.0000 - 210ms/epoch - 105ms/step
# Epoch 24/30
# 2/2 - 0s - loss: 0.0081 - accuracy: 1.0000 - 208ms/epoch - 104ms/step
# Epoch 25/30
# 2/2 - 0s - loss: 0.0079 - accuracy: 1.0000 - 208ms/epoch - 104ms/step
# Epoch 26/30
# 2/2 - 0s - loss: 0.0065 - accuracy: 1.0000 - 208ms/epoch - 104ms/step
# Epoch 27/30
# 2/2 - 0s - loss: 0.0061 - accuracy: 1.0000 - 210ms/epoch - 105ms/step
# Epoch 28/30
# 2/2 - 0s - loss: 0.0048 - accuracy: 1.0000 - 204ms/epoch - 102ms/step
# Epoch 29/30
# 2/2 - 0s - loss: 0.0047 - accuracy: 1.0000 - 212ms/epoch - 106ms/step
# Epoch 30/30
# 2/2 - 0s - loss: 0.0039 - accuracy: 1.0000 - 202ms/epoch - 101ms/step
# Tempo de treino: 7.96 s
# Test loss: 0.0631
# Test accuracy: 98.00 %
# Test error: 2.00 %
# 2/2 [==============================] - 0s 14ms/step
# Tamanho das matrizes: AX = (200, 250, 250) AY = (200,) QX = (50, 250, 250) QY = (50,)
# Epoch 1/30
# 2/2 - 2s - loss: 2.8760 - accuracy: 0.1500 - 2s/epoch - 1s/step
# Epoch 2/30
# 2/2 - 0s - loss: 1.9554 - accuracy: 0.6750 - 223ms/epoch - 111ms/step
# Epoch 3/30
# 2/2 - 0s - loss: 0.9080 - accuracy: 0.8950 - 214ms/epoch - 107ms/step
# Epoch 4/30
# 2/2 - 0s - loss: 0.5653 - accuracy: 0.7300 - 216ms/epoch - 108ms/step
# Epoch 5/30
# 2/2 - 0s - loss: 0.2857 - accuracy: 0.9050 - 214ms/epoch - 107ms/step
# Epoch 6/30
# 2/2 - 0s - loss: 0.2657 - accuracy: 0.8400 - 214ms/epoch - 107ms/step
# Epoch 7/30
# 2/2 - 0s - loss: 0.1393 - accuracy: 0.9550 - 219ms/epoch - 109ms/step
# Epoch 8/30
# 2/2 - 0s - loss: 0.0928 - accuracy: 0.9550 - 211ms/epoch - 105ms/step
# Epoch 9/30
# 2/2 - 0s - loss: 0.0646 - accuracy: 0.9750 - 212ms/epoch - 106ms/step
# Epoch 10/30
# 2/2 - 0s - loss: 0.0588 - accuracy: 0.9800 - 213ms/epoch - 106ms/step
# Epoch 11/30
# 2/2 - 0s - loss: 0.0490 - accuracy: 0.9800 - 213ms/epoch - 106ms/step
# Epoch 12/30
# 2/2 - 0s - loss: 0.0428 - accuracy: 0.9850 - 213ms/epoch - 106ms/step
# Epoch 13/30
# 2/2 - 0s - loss: 0.0341 - accuracy: 0.9950 - 209ms/epoch - 105ms/step
# Epoch 14/30
# 2/2 - 0s - loss: 0.0215 - accuracy: 0.9900 - 214ms/epoch - 107ms/step
# Epoch 15/30
# 2/2 - 0s - loss: 0.0223 - accuracy: 0.9900 - 218ms/epoch - 109ms/step
# Epoch 16/30
# 2/2 - 0s - loss: 0.0135 - accuracy: 0.9950 - 214ms/epoch - 107ms/step
# Epoch 17/30
# 2/2 - 0s - loss: 0.0109 - accuracy: 1.0000 - 213ms/epoch - 106ms/step
# Epoch 18/30
# 2/2 - 0s - loss: 0.0090 - accuracy: 1.0000 - 212ms/epoch - 106ms/step
# Epoch 19/30
# 2/2 - 0s - loss: 0.0077 - accuracy: 1.0000 - 212ms/epoch - 106ms/step
# Epoch 20/30
# 2/2 - 0s - loss: 0.0067 - accuracy: 1.0000 - 214ms/epoch - 107ms/step
# Epoch 21/30
# 2/2 - 0s - loss: 0.0057 - accuracy: 1.0000 - 212ms/epoch - 106ms/step
# Epoch 22/30
# 2/2 - 0s - loss: 0.0047 - accuracy: 1.0000 - 208ms/epoch - 104ms/step
# Epoch 23/30
# 2/2 - 0s - loss: 0.0046 - accuracy: 1.0000 - 213ms/epoch - 107ms/step
# Epoch 24/30
# 2/2 - 0s - loss: 0.0040 - accuracy: 1.0000 - 217ms/epoch - 108ms/step
# Epoch 25/30
# 2/2 - 0s - loss: 0.0034 - accuracy: 1.0000 - 214ms/epoch - 107ms/step
# Epoch 26/30
# 2/2 - 0s - loss: 0.0030 - accuracy: 1.0000 - 213ms/epoch - 106ms/step
# Epoch 27/30
# 2/2 - 0s - loss: 0.0027 - accuracy: 1.0000 - 209ms/epoch - 104ms/step
# Epoch 28/30
# 2/2 - 0s - loss: 0.0023 - accuracy: 1.0000 - 213ms/epoch - 107ms/step
# Epoch 29/30
# 2/2 - 0s - loss: 0.0022 - accuracy: 1.0000 - 217ms/epoch - 108ms/step
# Epoch 30/30
# 2/2 - 0s - loss: 0.0020 - accuracy: 1.0000 - 204ms/epoch - 102ms/step
# Tempo de treino: 11.33 s
# Test loss: 0.2006
# Test accuracy: 94.00 %
# Test error: 6.00 %
# 2/2 [==============================] - 0s 13ms/step
# Tamanho das matrizes: AX = (200, 250, 250) AY = (200,) QX = (50, 250, 250) QY = (50,)
# Epoch 1/30
# 2/2 - 2s - loss: 1.9756 - accuracy: 0.3050 - 2s/epoch - 1s/step
# Epoch 2/30
# 2/2 - 0s - loss: 2.3846 - accuracy: 0.4350 - 253ms/epoch - 127ms/step
# Epoch 3/30
# 2/2 - 0s - loss: 0.6049 - accuracy: 0.8300 - 220ms/epoch - 110ms/step
# Epoch 4/30
# 2/2 - 0s - loss: 0.5282 - accuracy: 0.8200 - 215ms/epoch - 107ms/step
# Epoch 5/30
# 2/2 - 0s - loss: 0.2435 - accuracy: 0.8600 - 207ms/epoch - 104ms/step
# Epoch 6/30
# 2/2 - 0s - loss: 0.1469 - accuracy: 0.9350 - 214ms/epoch - 107ms/step
# Epoch 7/30
# 2/2 - 0s - loss: 0.1128 - accuracy: 0.9600 - 210ms/epoch - 105ms/step
# Epoch 8/30
# 2/2 - 0s - loss: 0.0869 - accuracy: 0.9650 - 215ms/epoch - 107ms/step
# Epoch 9/30
# 2/2 - 0s - loss: 0.0842 - accuracy: 0.9650 - 212ms/epoch - 106ms/step
# Epoch 10/30
# 2/2 - 0s - loss: 0.0557 - accuracy: 0.9850 - 211ms/epoch - 106ms/step
# Epoch 11/30
# 2/2 - 0s - loss: 0.0518 - accuracy: 0.9850 - 213ms/epoch - 106ms/step
# Epoch 12/30
# 2/2 - 0s - loss: 0.0501 - accuracy: 0.9750 - 213ms/epoch - 107ms/step
# Epoch 13/30
# 2/2 - 0s - loss: 0.0384 - accuracy: 0.9850 - 211ms/epoch - 106ms/step
# Epoch 14/30
# 2/2 - 0s - loss: 0.0366 - accuracy: 0.9950 - 208ms/epoch - 104ms/step
# Epoch 15/30
# 2/2 - 0s - loss: 0.0244 - accuracy: 0.9900 - 214ms/epoch - 107ms/step
# Epoch 16/30
# 2/2 - 0s - loss: 0.0245 - accuracy: 0.9900 - 209ms/epoch - 105ms/step
# Epoch 17/30
# 2/2 - 0s - loss: 0.0233 - accuracy: 0.9950 - 211ms/epoch - 105ms/step
# Epoch 18/30
# 2/2 - 0s - loss: 0.0190 - accuracy: 0.9950 - 213ms/epoch - 107ms/step
# Epoch 19/30
# 2/2 - 0s - loss: 0.0148 - accuracy: 0.9950 - 210ms/epoch - 105ms/step
# Epoch 20/30
# 2/2 - 0s - loss: 0.0151 - accuracy: 0.9950 - 208ms/epoch - 104ms/step
# Epoch 21/30
# 2/2 - 0s - loss: 0.0126 - accuracy: 0.9950 - 212ms/epoch - 106ms/step
# Epoch 22/30
# 2/2 - 0s - loss: 0.0141 - accuracy: 0.9950 - 211ms/epoch - 106ms/step
# Epoch 23/30
# 2/2 - 0s - loss: 0.0117 - accuracy: 0.9950 - 211ms/epoch - 106ms/step
# Epoch 24/30
# 2/2 - 0s - loss: 0.0091 - accuracy: 1.0000 - 213ms/epoch - 106ms/step
# Epoch 25/30
# 2/2 - 0s - loss: 0.0110 - accuracy: 1.0000 - 211ms/epoch - 105ms/step
# Epoch 26/30
# 2/2 - 0s - loss: 0.0073 - accuracy: 1.0000 - 209ms/epoch - 104ms/step
# Epoch 27/30
# 2/2 - 0s - loss: 0.0097 - accuracy: 0.9950 - 213ms/epoch - 106ms/step
# Epoch 28/30
# 2/2 - 0s - loss: 0.0047 - accuracy: 1.0000 - 212ms/epoch - 106ms/step
# Epoch 29/30
# 2/2 - 0s - loss: 0.0052 - accuracy: 1.0000 - 211ms/epoch - 105ms/step
# Epoch 30/30
# 2/2 - 0s - loss: 0.0064 - accuracy: 1.0000 - 208ms/epoch - 104ms/step
# Tempo de treino: 11.26 s
# Test loss: 0.0188
# Test accuracy: 98.00 %
# Test error: 2.00 %
# 2/2 [==============================] - 0s 13ms/step
# Tamanho das matrizes: AX = (200, 250, 250) AY = (200,) QX = (50, 250, 250) QY = (50,)
# Epoch 1/30
# 2/2 - 2s - loss: 4.5888 - accuracy: 0.2000 - 2s/epoch - 1s/step
# Epoch 2/30
# 2/2 - 0s - loss: 5.0911 - accuracy: 0.3450 - 238ms/epoch - 119ms/step
# Epoch 3/30
# 2/2 - 0s - loss: 2.4232 - accuracy: 0.4800 - 217ms/epoch - 108ms/step
# Epoch 4/30
# 2/2 - 0s - loss: 0.9225 - accuracy: 0.6650 - 212ms/epoch - 106ms/step
# Epoch 5/30
# 2/2 - 0s - loss: 0.6174 - accuracy: 0.7600 - 213ms/epoch - 107ms/step
# Epoch 6/30
# 2/2 - 0s - loss: 0.3716 - accuracy: 0.8950 - 219ms/epoch - 109ms/step
# Epoch 7/30
# 2/2 - 0s - loss: 0.3059 - accuracy: 0.8700 - 223ms/epoch - 112ms/step
# Epoch 8/30
# 2/2 - 0s - loss: 0.2176 - accuracy: 0.9200 - 217ms/epoch - 108ms/step
# Epoch 9/30
# 2/2 - 0s - loss: 0.1595 - accuracy: 0.9450 - 209ms/epoch - 104ms/step
# Epoch 10/30
# 2/2 - 0s - loss: 0.1125 - accuracy: 0.9550 - 218ms/epoch - 109ms/step
# Epoch 11/30
# 2/2 - 0s - loss: 0.0841 - accuracy: 0.9750 - 227ms/epoch - 113ms/step
# Epoch 12/30
# 2/2 - 0s - loss: 0.0590 - accuracy: 0.9800 - 216ms/epoch - 108ms/step
# Epoch 13/30
# 2/2 - 0s - loss: 0.0497 - accuracy: 0.9750 - 213ms/epoch - 106ms/step
# Epoch 14/30
# 2/2 - 0s - loss: 0.0534 - accuracy: 0.9900 - 213ms/epoch - 107ms/step
# Epoch 15/30
# 2/2 - 0s - loss: 0.0384 - accuracy: 0.9750 - 212ms/epoch - 106ms/step
# Epoch 16/30
# 2/2 - 0s - loss: 0.0452 - accuracy: 0.9800 - 207ms/epoch - 104ms/step
# Epoch 17/30
# 2/2 - 0s - loss: 0.0291 - accuracy: 0.9900 - 213ms/epoch - 107ms/step
# Epoch 18/30
# 2/2 - 0s - loss: 0.0299 - accuracy: 0.9850 - 218ms/epoch - 109ms/step
# Epoch 19/30
# 2/2 - 0s - loss: 0.0248 - accuracy: 0.9950 - 213ms/epoch - 107ms/step
# Epoch 20/30
# 2/2 - 0s - loss: 0.0213 - accuracy: 0.9900 - 211ms/epoch - 105ms/step
# Epoch 21/30
# 2/2 - 0s - loss: 0.0215 - accuracy: 0.9900 - 211ms/epoch - 105ms/step
# Epoch 22/30
# 2/2 - 0s - loss: 0.0261 - accuracy: 0.9900 - 213ms/epoch - 106ms/step
# Epoch 23/30
# 2/2 - 0s - loss: 0.0179 - accuracy: 0.9950 - 209ms/epoch - 105ms/step
# Epoch 24/30
# 2/2 - 0s - loss: 0.0154 - accuracy: 0.9950 - 210ms/epoch - 105ms/step
# Epoch 25/30
# 2/2 - 0s - loss: 0.0149 - accuracy: 0.9950 - 211ms/epoch - 106ms/step
# Epoch 26/30
# 2/2 - 0s - loss: 0.0105 - accuracy: 1.0000 - 215ms/epoch - 107ms/step
# Epoch 27/30
# 2/2 - 0s - loss: 0.0079 - accuracy: 1.0000 - 214ms/epoch - 107ms/step
# Epoch 28/30
# 2/2 - 0s - loss: 0.0130 - accuracy: 1.0000 - 211ms/epoch - 105ms/step
# Epoch 29/30
# 2/2 - 0s - loss: 0.0079 - accuracy: 1.0000 - 212ms/epoch - 106ms/step
# Epoch 30/30
# 2/2 - 0s - loss: 0.0107 - accuracy: 1.0000 - 204ms/epoch - 102ms/step
# Tempo de treino: 11.07 s
# Test loss: 0.0041
# Test accuracy: 100.00 %
# Test error: 0.00 %
# 2/2 [==============================] - 0s 13ms/step
#
#
# Resultados class_alin:  5-fold cross validation:
#
# Perda do Teste:  0.6183 0.0631 0.2006 0.0188 0.0041 Média: 0.181
# Acurácia do Teste:  0.94 0.98 0.94 0.98 1.0 Média: 0.968
# Erro do Teste:  0.06 0.02 0.06 0.02 0.0 Média: 0.032
